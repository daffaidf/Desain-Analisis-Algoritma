# %%
#swap function
var1 = 'kopi'
var2 = 'teh'
var1, var2 = var2, var1
print(var1, var2)
# Out:
# teh kopi

# %%
#swap function
var1 = 'kopi'
var2 = 'teh'
var3 = 'susu'
var1, var2, var3 = var3, var1, var2
print(var1, var2, var3)
# Out:
# susu kopi teh

# %%
list = [25,21,22,24,23,27,26]

lastElementIndex = len(list)-1
print(0,list)
for idx in range(lastElementIndex):
    if list[idx]>list[idx+1]:
        list[idx],list[idx+1]=list[idx+1],list[idx]
        print(idx+1,list)
# Out:
# 0 [25, 21, 22, 24, 23, 27, 26]
# 1 [21, 25, 22, 24, 23, 27, 26]
# 2 [21, 22, 25, 24, 23, 27, 26]
# 3 [21, 22, 24, 25, 23, 27, 26]
# 4 [21, 22, 24, 23, 25, 27, 26]
# 6 [21, 22, 24, 23, 25, 26, 27]

# %%
def Bubblesort(list):
    lastElementIndex = len(list)-1
    for i in range(lastElementIndex):
        for idx in range(lastElementIndex-i):
            if list[idx]>list[idx+1]:
                list[idx],list[idx+1]=list[idx+1],list[idx]
    return list

# %%
list = [21,22,23,24,25,26,27]
def Bubbleshor(list):
    lastElementIndex = len(list)-1
    for i in range(lastElementIndex):
        for idx in range(lastElementIndex-i):
            if list[idx]>list[idx+1]:
                list[idx],list[idx+1]=list[idx+1],list[idx]
    return list

# %%
data = [100,20,60,90,40,30,10]
print("Data awal:",data)

n = len(data)
for i in range(n):
    for j in range(0, n-i-1):
        if data[j] > data[j+1]:
            data[j], data[j+1] = data[j+1], data[j]
    print(f"Setelah pass{i+1}:",data)

    print("\nHasil akhir(Bubble Sort):",data)
# Out:
# Data awal: [100, 20, 60, 90, 40, 30, 10]
# Setelah pass1: [20, 60, 90, 40, 30, 10, 100]
#
# Hasil akhir(Bubble Sort): [20, 60, 90, 40, 30, 10, 100]
# Setelah pass2: [20, 60, 40, 30, 10, 90, 100]
#
# Hasil akhir(Bubble Sort): [20, 60, 40, 30, 10, 90, 100]
# Setelah pass3: [20, 40, 30, 10, 60, 90, 100]
#
# Hasil akhir(Bubble Sort): [20, 40, 30, 10, 60, 90, 100]
# Setelah pass4: [20, 30, 10, 40, 60, 90, 100]
#
# Hasil akhir(Bubble Sort): [20, 30, 10, 40, 60, 90, 100]
# Setelah pass5: [20, 10, 30, 40, 60, 90, 100]
#
# Hasil akhir(Bubble Sort): [20, 10, 30, 40, 60, 90, 100]
# Setelah pass6: [10, 20, 30, 40, 60, 90, 100]
#
# Hasil akhir(Bubble Sort): [10, 20, 30, 40, 60, 90, 100]
# Setelah pass7: [10, 20, 30, 40, 60, 90, 100]
#
# Hasil akhir(Bubble Sort): [10, 20, 30, 40, 60, 90, 100]

# %%
def insertionSort(list):
    for i in range(1, len(list)):
        j = i-1
        next = list[i]
        while (list[j] > next) and (j >= 0):
            list[j + 1] = list[j]
            j = j-1
        list[j + 1] = next
    return list

# %%
list = [35,31,32,34,33,37,36]

# %%
list
# Out:
# [35, 31, 32, 34, 33, 37, 36]

# %%
insertionSort(list)
# Out:
# [31, 32, 33, 34, 35, 36, 37]

# %%
def insertionSort(lst):
    for i in range(1,len(lst)):
        j = i-1
        kunci = lst[i] #ambil elemen saat ini
        while (lst[j] > kunci) and (j >= 0):
            lst[j + 1] = lst[j] #geser elemen ke kanan
            j = j-1
        lst[j + 1] = kunci #sisipkan kunci di posisi yang tepat
    return lst

data = [89,12,57,16,25,11,75]
print("Data awal:",data)
hasil = insertionSort(data)
print("Hasil akhir",hasil)
# Out:
# Data awal: [89, 12, 57, 16, 25, 11, 75]
# Hasil akhir [11, 12, 16, 25, 57, 75, 89]

# %%
def selectionSort(list):
    for fill_slot in range(len(list)-1,0,-1):
        maxIndex = 0
        for location in range(1,fill_slot+1):
            if list[location]>list[maxIndex]:
                maxIndex = location
        list[fill_slot],list[maxIndex]=list[maxIndex],list[fill_slot]
    return list

list = [70,15,25,19,34,44,]
selectionSort(list)
# Out:
# [15, 19, 25, 34, 44, 70]

# %%
def SelectionSort(list):
    for fill_slot in range(len(list)-1,0,-1):
        maxIndex = 0
        for location in range(1,fill_slot+1):
            if list[location]>list[maxIndex]:
                maxIndex = location
        list[fill_slot],list[maxIndex]=list[maxIndex],list[fill_slot]
    return list

data = [89,12,57,16,25]
print("Data awal:",data)
hasil = SelectionSort(data)
print("Hasil akhir",hasil)
# Out:
# Data awal: [89, 12, 57, 16, 25]
# Hasil akhir [12, 16, 25, 57, 89]

# %%
def LinearSearch(list, item):
    index = 0
    found = False

    while index < len(list) and not found:
        if list[index] == item:
            found = True
        else:
            index = index + 1
    return found

list = [12,33,11,99,22,55,90]
print(LinearSearch(list, 12))
print(LinearSearch(list, 91))
# Out:
# True
# False

# %%
def LinearSearch(lst,item):
    if lst[index]==item:
        found = True
    else:
        index = index + 1   
    return found, index if found else -1

    data = ['y','u','i','w','o','a','q','u','j','p']
    print("Data:",data)

    cari = 'a'
    ketemu, posisi = LinearSearch(data,cari)

    if ketemu:
        print(f"Huruf'{cari}'ditemukan di index ke-{posisi}")
    else:
        print(f"Huruf'{cari}'tidak ditemukan")

# %%
def BubbleSort(lst):
    n = len(lst)
    for i in range(n):
        for j in range(0, n - i - 1):
            if lst[j] > lst[j + 1]:
                var3 = lst[j]
                lst[j] = lst[j + 1]
                lst[j + 1] = var3
    return lst

def BinarySearch(lst, item):
    first = 0
    last = len(lst) - 1
    found = False

    while first <= last and not found:
        midpoint = (first + last) // 2
        if lst[midpoint] == item:
            found = True
        else:
            if item < lst[midpoint]:
                last = midpoint - 1
            else:
                first = midpoint + 1
    return found

data = [12, 33, 11, 99, 22, 55, 90]
sorted_lst = BubbleSort(data)
print(BinarySearch(sorted_lst, 12))  # True karena 12 ada
print(BinarySearch(sorted_lst, 91))  # False karena 91 tidak ada
# Out:
# True
# False

# %%
def BubbleSort(lst):  # <- Tambahkan titik dua di sini
    n = len(lst)
    for i in range(n):
        for j in range(0, n - i - 1):
            if lst[j] > lst[j + 1]:
                var3 = lst[j]
                lst[j] = lst[j + 1]
                lst[j + 1] = var3
    return lst

def BinarySearch(lst, item):
    first = 0
    last = len(lst) - 1
    found = False

    while first <= last and not found:
        midpoint = (first + last) // 2
        if lst[midpoint] == item:
            found = True
        else:
            if item < lst[midpoint]:
                last = midpoint - 1
            else:
                first = midpoint + 1
    return found

data = ['y','u','i','w','o','a','q','u','j','p']
print("Data awal:", data)
sorted_data = BubbleSort(data)
print("Data setelah sort:", sorted_data)
print("cari 'a':", BinarySearch(sorted_data, 'a'))  # True karena 'a' ada
print("cari 'z':", BinarySearch(sorted_data, 'z'))  # False karena 'z' tidak ada
# Out:
# Data awal: ['y', 'u', 'i', 'w', 'o', 'a', 'q', 'u', 'j', 'p']
# Data setelah sort: ['a', 'i', 'j', 'o', 'p', 'q', 'u', 'u', 'w', 'y']
# cari 'a': True
# cari 'z': False
