# %%
import  datetime    

x = datetime.datetime(2022, 12,31)
print(x)

today = datetime.date.today()

mahasiswa = ["Muhammad Daffa Rinaldi", 2024071024, "Informatika", "DAA", "Universitas Pembangunan jaya", today]
print(mahasiswa)
# Out:
# 2022-12-31 00:00:00
# ['Muhammad Daffa Rinaldi', 2024071024, 'Informatika', 'DAA', 'Universitas Pembangunan jaya', datetime.date(2025, 9, 15)]

# %%
print("NIM dan Prodi", mahasiswa[1:3])
# Out:
# NIM dan Prodi [2024071024, 'Informatika']

# %%
print("NIM", mahasiswa[1])
# Out:
# NIM 2024071024

# %%
mahasiswa[4]
# Out:
# 'Universitas Pembangunan jaya'

# %%
for xmahasiswa in mahasiswa:
    print(str(xmahasiswa) + " UPJ")
# Out:
# Muhammad Daffa Rinaldi UPJ
# 2024071024 UPJ
# Informatika UPJ
# DAA UPJ
# Universitas Pembangunan jaya UPJ
# 2025-09-15 UPJ

# %%
UPJ = ["Universitas", "Pembangunan", "Jaya"]
print(" ".join(UPJ))
# Out:
# Universitas Pembangunan Jaya

# %%
bin_colors=['Red', 'Green', 'Blue', 'Yellow']
for aColor in bin_colors:
    print(aColor + " square")
# Out:
# Red square
# Green square
# Blue square
# Yellow square

# %%
nested_tuple = (100,(200,400,600),300,(400,800))
print(nested_tuple[1][1])
# Out:
# 400

# %%
nama = {
    "Nama": "Muhammad Daffa Rinaldi",
    "NIM" : 2024071024,
    "Prodi" : "Informatika",
    "Universitas" : "Universitas Pembangunan Jaya"
}
print(nama)
# Out:
# {'Nama': 'Muhammad Daffa Rinaldi', 'NIM': 2024071024, 'Prodi': 'Informatika', 'Universitas': 'Universitas Pembangunan Jaya'}

# %%
import pandas as pd

data = {
    'No': [1, 2, 3],
    'Prodi': ['Informatika', 'Sisten Informasi', 'Teknik Sipil'],
    'Mahasiswa': [50, 55, 40],
    'Laki-laki': [30, 30, 30],
    'Perempuan': [20, 25, 10],
}
df = pd.DataFrame(data)
print(df.to_string(index=False))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 import pandas as pd
#       3 data = {
#       4     'No': [1, 2, 3],
#       5     'Prodi': ['Informatika', 'Sisten Informasi', 'Teknik Sipil'],
#    (...)      8     'Perempuan': [20, 25, 10],
#       9 }
#      10 df = pd.DataFrame(data)
#
# ModuleNotFoundError: No module named 'pandas'
